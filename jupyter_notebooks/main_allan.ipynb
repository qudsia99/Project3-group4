# %%
# Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
from pathlib import Path
#Filters warnings
from warnings import filterwarnings

# %%
#Loading file into Path
data = Path('../Resources/income_data.csv')
#Reading income data file
income_df = pd.read_csv(data)
income_df.head()
# Out:
#    REF_DATE     GEO           DGUID         Sex  \
# 0      2012  Canada  2016A000011124  Both sexes
# 1      2012  Canada  2016A000011124  Both sexes
# 2      2012  Canada  2016A000011124  Both sexes
# 3      2012  Canada  2016A000011124  Both sexes
# 4      2012  Canada  2016A000011124  Both sexes
#
#                         Work activity  \
# 0  All persons with employment income
# 1  All persons with employment income
# 2  All persons with employment income
# 3  All persons with employment income
# 4  All persons with employment income
#
#                                    Statistics                    UOM  UOM_ID  \
# 0                           Number of persons                 Number     223
# 1                   Average employment income  2021 constant dollars     429
# 2                    Median employment income  2021 constant dollars     429
# 3  Percentage under $5,000 (including losses)                Percent     239
# 4                            $5,000 to $9,999                Percent     239
#
#   SCALAR_FACTOR  SCALAR_ID      VECTOR COORDINATE    VALUE STATUS  SYMBOL  \
# 0     thousands          3  v107657641    1.1.1.1  20070.0      A     NaN
# 1         units          0  v107657642    1.1.1.2  47900.0      A     NaN
# 2         units          0  v107657643    1.1.1.3  36200.0      A     NaN
# 3         units          0  v107657644    1.1.1.4     12.3      A     NaN
# 4         units          0  v107657645    1.1.1.5      8.1      B     NaN
#
#    TERMINATED  DECIMALS
# 0         NaN         0
# 1         NaN         0
# 2         NaN         0
# 3         NaN         1
# 4         NaN         1

# %%
#REmove columns, DGUID, Sex, REmove UOM ID, scalar factor, scalar id, coordinate, symbol, terminated, decimals
income_df = income_df.drop(columns = ['DGUID', 'Sex', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'COORDINATE', 'SYMBOL', 'TERMINATED', 'DECIMALS', 'STATUS'])
income_df.head()
# Out:
#    REF_DATE     GEO                       Work activity  \
# 0      2012  Canada  All persons with employment income
# 1      2012  Canada  All persons with employment income
# 2      2012  Canada  All persons with employment income
# 3      2012  Canada  All persons with employment income
# 4      2012  Canada  All persons with employment income
#
#                                    Statistics                    UOM  \
# 0                           Number of persons                 Number
# 1                   Average employment income  2021 constant dollars
# 2                    Median employment income  2021 constant dollars
# 3  Percentage under $5,000 (including losses)                Percent
# 4                            $5,000 to $9,999                Percent
#
#        VECTOR    VALUE
# 0  v107657641  20070.0
# 1  v107657642  47900.0
# 2  v107657643  36200.0
# 3  v107657644     12.3
# 4  v107657645      8.1

# %%
#Renaming Columns 
new_income_df = income_df.rename(columns={
        "REF_DATE" : "Year",
        "GEO" : "Province",
        "Work activity" : "Employment Type",
        "Statistics" : "Type of Statistic",
        "UOM" : "Unit of Measure",
        "VECTOR" : "Vector ID",
        "VALUE": "Value"
                                }                                 
                                 )

# %%
#Rearranging the Columns
new_income_df = new_income_df[['Vector ID', 'Year', 'Province', 'Employment Type','Type of Statistic',
       'Unit of Measure', 'Value']]
new_income_df.head()
# Out:
#     Vector ID  Year Province                     Employment Type  \
# 0  v107657641  2012   Canada  All persons with employment income
# 1  v107657642  2012   Canada  All persons with employment income
# 2  v107657643  2012   Canada  All persons with employment income
# 3  v107657644  2012   Canada  All persons with employment income
# 4  v107657645  2012   Canada  All persons with employment income
#
#                             Type of Statistic        Unit of Measure    Value
# 0                           Number of persons                 Number  20070.0
# 1                   Average employment income  2021 constant dollars  47900.0
# 2                    Median employment income  2021 constant dollars  36200.0
# 3  Percentage under $5,000 (including losses)                Percent     12.3
# 4                            $5,000 to $9,999                Percent      8.1

# %%
#Filtering Data by Year 
#condition1 = df['Column1'].str.contains('a')
year_income_df = new_income_df.loc[new_income_df['Year'] > 2018, :]
emp_income_df = year_income_df.loc[year_income_df['Employment Type'] == 'All persons with employment income', :]
#Alberta


# Defining a list of provinces and territories
pt = ['Alberta', 'British Columbia', 'Manitoba', 'New Brunswick', 'Newfoundland and Labrador', 'Nova Scotia', 'Ontario', 'Prince Edward Island', 'Quebec', 'Saskatchewan']

# Check if values in 'Province' are in the list of provinces and territories
filter_condition = emp_income_df['Province'].isin(pt)

#Filtered Provinces & territories data 
province_income_df = emp_income_df[filter_condition]
clean_income_df = province_income_df
clean_income_df.head(50)
# Out:
#         Vector ID  Year                   Province  \
# 22797  v107657947  2019  Newfoundland and Labrador
# 22798  v107657948  2019  Newfoundland and Labrador
# 22799  v107657949  2019  Newfoundland and Labrador
# 22800  v107657950  2019  Newfoundland and Labrador
# 22801  v107657951  2019  Newfoundland and Labrador
# 22802  v107657952  2019  Newfoundland and Labrador
# 22803  v107657953  2019  Newfoundland and Labrador
# 22804  v107657954  2019  Newfoundland and Labrador
# 22805  v107657955  2019  Newfoundland and Labrador
# 22806  v107657956  2019  Newfoundland and Labrador
# 22807  v107657957  2019  Newfoundland and Labrador
# 22808  v107657958  2019  Newfoundland and Labrador
# 22809  v107657959  2019  Newfoundland and Labrador
# 22810  v107657960  2019  Newfoundland and Labrador
# 22811  v107657961  2019  Newfoundland and Labrador
# 22812  v107657962  2019  Newfoundland and Labrador
# 22813  v107657963  2019  Newfoundland and Labrador
# 22848  v107657998  2019  Newfoundland and Labrador
# 22849  v107657999  2019  Newfoundland and Labrador
# 22850  v107658000  2019  Newfoundland and Labrador
# 22851  v107658001  2019  Newfoundland and Labrador
# 22852  v107658002  2019  Newfoundland and Labrador
# 22853  v107658003  2019  Newfoundland and Labrador
# 22854  v107658004  2019  Newfoundland and Labrador
# 22855  v107658005  2019  Newfoundland and Labrador
# 22856  v107658006  2019  Newfoundland and Labrador
# 22857  v107658007  2019  Newfoundland and Labrador
# 22858  v107658008  2019  Newfoundland and Labrador
# 22859  v107658009  2019  Newfoundland and Labrador
# 22860  v107658010  2019  Newfoundland and Labrador
# 22805                          $40,000 to $49,999                Percent
# 22806                          $50,000 to $59,999                Percent
# 22807                          $60,000 to $79,999                Percent
# 22808                          $60,000 to $69,999                Percent
# 22809                          $70,000 to $79,999                Percent
# 22810                          $80,000 to $99,999                Percent
# 22811                          $80,000 to $89,999                Percent
# 22812                          $90,000 to $99,999                Percent
# 22813                           $100,000 and over                Percent
# 22848                           Number of persons                 Number
# 22849                   Average employment income  2021 constant dollars
# 22850                    Median employment income  2021 constant dollars
# 22851  Percentage under $5,000 (including losses)                Percent
# 22852                            $5,000 to $9,999                Percent
# 22853                          $10,000 to $19,999                Percent
# 22854                          $20,000 to $29,999                Percent
# 22855                          $30,000 to $39,999                Percent
# 22856                          $40,000 to $49,999                Percent
# 22857                          $50,000 to $59,999                Percent
# 22858                          $60,000 to $79,999                Percent
# 22859                          $60,000 to $69,999                Percent
# 22860                          $70,000 to $79,999                Percent
# 22861                          $80,000 to $99,999                Percent
# 22862                          $80,000 to $89,999                Percent
# 22863                          $90,000 to $99,999                Percent
# 22864                           $100,000 and over                Percent
# 22899                           Number of persons                 Number
# 22900                   Average employment income  2021 constant dollars
# 22901                    Median employment income  2021 constant dollars
# 22902  Percentage under $5,000 (including losses)                Percent
# 22903                            $5,000 to $9,999                Percent
# 22904                          $10,000 to $19,999                Percent
# 22905                          $20,000 to $29,999                Percent
# 22906                          $30,000 to $39,999                Percent
# 22907                          $40,000 to $49,999                Percent
# 22908                          $50,000 to $59,999                Percent
# 22909                          $60,000 to $79,999                Percent
# 22910                          $60,000 to $69,999                Percent
# 22911                          $70,000 to $79,999                Percent
# 22912                          $80,000 to $99,999                Percent
# 22913                          $80,000 to $89,999                Percent
# 22914                          $90,000 to $99,999                Percent
#
#          Value
# 22797    292.0
# 22798  48000.0
# 22799  33100.0
# 22800     12.3
# 22801      7.2
# 22802     14.9
# 22803     12.3
# 22804      7.8
# 22805      9.5
# 22806      5.6
# 22807     10.7
# 22808      6.6
# 22809      4.1
# 22810      7.7
# 22811      4.7
# 22812      3.0
# 22813     12.1
# 22848    150.0
# 22849  57500.0
# 22850  42900.0
# 22851      9.9
# 22852      5.7
# 22853     12.9
# 22854     10.8
# 22855      7.0
# 22856      9.6
# 22857      6.1
# 22858     12.1
# 22859      7.9
# 22860      4.2
# 22861      7.7
# 22862      4.6
# 22863      3.0
# 22864     18.1
# 22899    142.0
# 22900  38100.0
# 22901  26300.0
# 22902     14.8
# 22903      8.8
# 22904     17.0
# 22905     13.9
# 22906      8.6
# 22907      9.4
# 22908      5.0
# 22909      9.1
# 22910      5.2
# 22911      3.9
# 22912      7.7
# 22913      4.7
# 22914      NaN

# %%
#Output Data
clean_income_df.to_csv("../Output/clean_income_data.csv", index = False)
