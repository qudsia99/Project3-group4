# %%
# Import Dependecies

import pandas as pd
import numpy as np
import csv 
import matplotlib.pyplot as plt
from pathlib import Path
import scipy.stats as st

# %%
# Creating path to CSV file
employment_file = Path('../../Resources/employment_data.csv')

# Reading the CSV
employ_df = pd.read_csv(employment_file)

# Display CSV
employ_df
# Out:
#         REF_DATE               GEO           DGUID  \
# 0           1976            Canada  2016A000011124
# 1           1976            Canada  2016A000011124
# 2           1976            Canada  2016A000011124
# 3           1976            Canada  2016A000011124
# 4           1976            Canada  2016A000011124
# ...          ...               ...             ...
# 409459      2022  British Columbia     2016A000259
# 409460      2022  British Columbia     2016A000259
# 409461      2022  British Columbia     2016A000259
# 409462      2022  British Columbia     2016A000259
# 409463      2022  British Columbia     2016A000259
#
#        Labour force characteristics         Sex          Age group  \
# 0                        Population  Both sexes  15 years and over
# 1                        Population  Both sexes     15 to 24 years
# 2                        Population  Both sexes  25 years and over
# 3                        Population  Both sexes     25 to 44 years
# 4                        Population  Both sexes     45 to 64 years
# ...                             ...         ...                ...
# 409459              Employment rate     Females     55 to 59 years
# 409460              Employment rate     Females     60 to 64 years
# 409461              Employment rate     Females  65 years and over
# 409462              Employment rate     Females     65 to 69 years
# 409463              Employment rate     Females  70 years and over
#
#                UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID       VECTOR  COORDINATE  \
# 0          Persons     249         units          0  v1063541342     1.1.1.1
# 1          Persons     249         units          0  v1063541343     1.1.1.2
# 2          Persons     249         units          0  v1063541344     1.1.1.3
# 3          Persons     249         units          0  v1063541345     1.1.1.4
# 4          Persons     249         units          0  v1063541363    1.1.1.22
# ...            ...     ...           ...        ...          ...         ...
# 409459  Percentage     242         units          0  v1063549916  11.10.3.17
# 409460  Percentage     242         units          0  v1063549917  11.10.3.18
# 409461  Percentage     242         units          0  v1063549918  11.10.3.19
# 409462  Percentage     242         units          0  v1063549919  11.10.3.20
# 409463  Percentage     242         units          0  v1063549920  11.10.3.21
#
#           VALUE STATUS  SYMBOL  TERMINATED  DECIMALS
# 0       17058.0    NaN     NaN         NaN         1
# 1        4550.4    NaN     NaN         NaN         1
# 2       12507.6    NaN     NaN         NaN         1
# 3        6259.7    NaN     NaN         NaN         1
# 4        4376.9    NaN     NaN         NaN         1
# ...         ...    ...     ...         ...       ...
# 409459     68.6    NaN     NaN         NaN         1
# 409460     49.9    NaN     NaN         NaN         1
# 409461     11.5    NaN     NaN         NaN         1
# 409462     24.7    NaN     NaN         NaN         1
# 409463      5.4    NaN     NaN         NaN         1
#
# [409464 rows x 17 columns]

# %%
# Check and browse columns
employ_df.columns
# Out:
# Index(['REF_DATE', 'GEO', 'DGUID', 'Labour force characteristics', 'Sex',
#        'Age group', 'UOM', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR',
#        'COORDINATE', 'VALUE', 'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS'],
#       dtype='object')

# %%
# Drop irrelevant columns and rearrange remaining
reduced_df = employ_df[['VECTOR','REF_DATE','GEO', 'Labour force characteristics','Sex',
        'UOM','VALUE', 'COORDINATE']]

reduced_df
# Out:
#              VECTOR  REF_DATE               GEO Labour force characteristics  \
# 0       v1063541342      1976            Canada                   Population
# 1       v1063541343      1976            Canada                   Population
# 2       v1063541344      1976            Canada                   Population
# 3       v1063541345      1976            Canada                   Population
# 4       v1063541363      1976            Canada                   Population
# ...             ...       ...               ...                          ...
# 409459  v1063549916      2022  British Columbia              Employment rate
# 409460  v1063549917      2022  British Columbia              Employment rate
# 409461  v1063549918      2022  British Columbia              Employment rate
# 409462  v1063549919      2022  British Columbia              Employment rate
# 409463  v1063549920      2022  British Columbia              Employment rate
#
#                Sex         UOM    VALUE  COORDINATE
# 0       Both sexes     Persons  17058.0     1.1.1.1
# 1       Both sexes     Persons   4550.4     1.1.1.2
# 2       Both sexes     Persons  12507.6     1.1.1.3
# 3       Both sexes     Persons   6259.7     1.1.1.4
# 4       Both sexes     Persons   4376.9    1.1.1.22
# ...            ...         ...      ...         ...
# 409459     Females  Percentage     68.6  11.10.3.17
# 409460     Females  Percentage     49.9  11.10.3.18
# 409461     Females  Percentage     11.5  11.10.3.19
# 409462     Females  Percentage     24.7  11.10.3.20
# 409463     Females  Percentage      5.4  11.10.3.21
#
# [409464 rows x 8 columns]

# %%
# Rename columns 
renamed_df = reduced_df.rename(columns={
     "VECTOR" : "Vector ID",
     "REF_DATE" : "Year",
     "GEO" : "Province",
     "UOM" : "Unit of Measure",
     "VALUE": "Value",
     "COORDINATE" : "Coordinate"
})

renamed_df.head()
# Out:
#      Vector ID  Year Province Labour force characteristics         Sex  \
# 0  v1063541342  1976   Canada                   Population  Both sexes
# 1  v1063541343  1976   Canada                   Population  Both sexes
# 2  v1063541344  1976   Canada                   Population  Both sexes
# 3  v1063541345  1976   Canada                   Population  Both sexes
# 4  v1063541363  1976   Canada                   Population  Both sexes
#
#   Unit of Measure    Value Coordinate
# 0         Persons  17058.0    1.1.1.1
# 1         Persons   4550.4    1.1.1.2
# 2         Persons  12507.6    1.1.1.3
# 3         Persons   6259.7    1.1.1.4
# 4         Persons   4376.9   1.1.1.22

# %% [markdown]
# # Data Clean up: Limit data to years 2019-2021 only and remove combined values in columns (such as 'Canada' in 'Province)

# %%
# Filtering by the years 2019-2021
years_df = renamed_df.loc[renamed_df['Year'].isin([2019, 2020, 2021])]
years_df
# Out:
#           Vector ID  Year          Province Labour force characteristics  \
# 374616  v1063541342  2019            Canada                   Population
# 374617  v1063541343  2019            Canada                   Population
# 374618  v1063541344  2019            Canada                   Population
# 374619  v1063541345  2019            Canada                   Population
# 374620  v1063541363  2019            Canada                   Population
# ...             ...   ...               ...                          ...
# 400747  v1063549916  2021  British Columbia              Employment rate
# 400748  v1063549917  2021  British Columbia              Employment rate
# 400749  v1063549918  2021  British Columbia              Employment rate
# 400750  v1063549919  2021  British Columbia              Employment rate
# 400751  v1063549920  2021  British Columbia              Employment rate
#
#                Sex Unit of Measure    Value  Coordinate
# 374616  Both sexes         Persons  30694.8     1.1.1.1
# 374617  Both sexes         Persons   4482.9     1.1.1.2
# 374618  Both sexes         Persons  26211.9     1.1.1.3
# 374619  Both sexes         Persons   9977.6     1.1.1.4
# 374620  Both sexes         Persons   9955.2    1.1.1.22
# ...            ...             ...      ...         ...
# 400747     Females      Percentage     67.8  11.10.3.17
# 400748     Females      Percentage     49.6  11.10.3.18
# 400749     Females      Percentage     10.1  11.10.3.19
# 400750     Females      Percentage     21.1  11.10.3.20
# 400751     Females      Percentage      5.0  11.10.3.21
#
# [26136 rows x 8 columns]

# %%
# Drop all rows where the 'Province' is has string values of 'Canada'
years_df = years_df.query('Province != "Canada"')
years_df
# Out:
#           Vector ID  Year                   Province  \
# 375408  v1063542134  2019  Newfoundland and Labrador
# 375409  v1063542135  2019  Newfoundland and Labrador
# 375410  v1063542136  2019  Newfoundland and Labrador
# 375411  v1063542137  2019  Newfoundland and Labrador
# 375412  v1063542155  2019  Newfoundland and Labrador
# ...             ...   ...                        ...
# 400747  v1063549916  2021           British Columbia
# 400748  v1063549917  2021           British Columbia
# 400749  v1063549918  2021           British Columbia
# 400750  v1063549919  2021           British Columbia
# 400751  v1063549920  2021           British Columbia
#
#        Labour force characteristics         Sex Unit of Measure  Value  \
# 375408                   Population  Both sexes         Persons  445.8
# 375409                   Population  Both sexes         Persons   55.4
# 375410                   Population  Both sexes         Persons  390.4
# 375411                   Population  Both sexes         Persons  119.0
# 375412                   Population  Both sexes         Persons  162.4
# ...                             ...         ...             ...    ...
# 400747              Employment rate     Females      Percentage   67.8
# 400748              Employment rate     Females      Percentage   49.6
# 400749              Employment rate     Females      Percentage   10.1
# 400750              Employment rate     Females      Percentage   21.1
# 400751              Employment rate     Females      Percentage    5.0
#
#         Coordinate
# 375408     2.1.1.1
# 375409     2.1.1.2
# 375410     2.1.1.3
# 375411     2.1.1.4
# 375412    2.1.1.22
# ...            ...
# 400747  11.10.3.17
# 400748  11.10.3.18
# 400749  11.10.3.19
# 400750  11.10.3.20
# 400751  11.10.3.21
#
# [23760 rows x 8 columns]

# %%
# Drop rows where 'Sex' = 'Both sexes' due to repitition of data
sex_df = years_df.query('Sex != "Both sexes"')
sex_df
# Out:
#           Vector ID  Year                   Province  \
# 375430  v1063542156  2019  Newfoundland and Labrador
# 375431  v1063542157  2019  Newfoundland and Labrador
# 375432  v1063542158  2019  Newfoundland and Labrador
# 375433  v1063542159  2019  Newfoundland and Labrador
# 375434  v1063542177  2019  Newfoundland and Labrador
# ...             ...   ...                        ...
# 400747  v1063549916  2021           British Columbia
# 400748  v1063549917  2021           British Columbia
# 400749  v1063549918  2021           British Columbia
# 400750  v1063549919  2021           British Columbia
# 400751  v1063549920  2021           British Columbia
#
#        Labour force characteristics      Sex Unit of Measure  Value  \
# 375430                   Population    Males         Persons  219.2
# 375431                   Population    Males         Persons   28.9
# 375432                   Population    Males         Persons  190.4
# 375433                   Population    Males         Persons   58.6
# 375434                   Population    Males         Persons   79.6
# ...                             ...      ...             ...    ...
# 400747              Employment rate  Females      Percentage   67.8
# 400748              Employment rate  Females      Percentage   49.6
# 400749              Employment rate  Females      Percentage   10.1
# 400750              Employment rate  Females      Percentage   21.1
# 400751              Employment rate  Females      Percentage    5.0
#
#         Coordinate
# 375430     2.1.2.1
# 375431     2.1.2.2
# 375432     2.1.2.3
# 375433     2.1.2.4
# 375434    2.1.2.22
# ...            ...
# 400747  11.10.3.17
# 400748  11.10.3.18
# 400749  11.10.3.19
# 400750  11.10.3.20
# 400751  11.10.3.21
#
# [15840 rows x 8 columns]

# %%
# Resetting the index
df = sex_df.reset_index(drop=True)
df
# Out:
#          Vector ID  Year                   Province  \
# 0      v1063542156  2019  Newfoundland and Labrador
# 1      v1063542157  2019  Newfoundland and Labrador
# 2      v1063542158  2019  Newfoundland and Labrador
# 3      v1063542159  2019  Newfoundland and Labrador
# 4      v1063542177  2019  Newfoundland and Labrador
# ...            ...   ...                        ...
# 15835  v1063549916  2021           British Columbia
# 15836  v1063549917  2021           British Columbia
# 15837  v1063549918  2021           British Columbia
# 15838  v1063549919  2021           British Columbia
# 15839  v1063549920  2021           British Columbia
#
#       Labour force characteristics      Sex Unit of Measure  Value  Coordinate
# 0                       Population    Males         Persons  219.2     2.1.2.1
# 1                       Population    Males         Persons   28.9     2.1.2.2
# 2                       Population    Males         Persons  190.4     2.1.2.3
# 3                       Population    Males         Persons   58.6     2.1.2.4
# 4                       Population    Males         Persons   79.6    2.1.2.22
# ...                            ...      ...             ...    ...         ...
# 15835              Employment rate  Females      Percentage   67.8  11.10.3.17
# 15836              Employment rate  Females      Percentage   49.6  11.10.3.18
# 15837              Employment rate  Females      Percentage   10.1  11.10.3.19
# 15838              Employment rate  Females      Percentage   21.1  11.10.3.20
# 15839              Employment rate  Females      Percentage    5.0  11.10.3.21
#
# [15840 rows x 8 columns]

# %%
# Confirming datatypes
df.dtypes
# Out:
# Vector ID                        object
# Year                              int64
# Province                         object
# Labour force characteristics     object
# Sex                              object
# Unit of Measure                  object
# Value                           float64
# Coordinate                       object
# dtype: object

# %% [markdown]
# # Employement data can now easily be accessed and filtered by 'Labour force characteristics' types (unemployement,part-time employment etc)

# %%
# Store cleaned file, to a new CSV 
df.to_csv('../../Output/employement_clean.csv', header= True, index= True)
